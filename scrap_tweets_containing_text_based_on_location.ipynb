# %%
import pandas as pd
import snscrape.modules.twitter as sntwitter
import itertools

# %%
num_of_tweets = 10
text_contained = "kilimo"
location = "dar es salaam"

# %%
data = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(text_contained+" "+'near:'+location).get_items(), 10))

# %%
data.head()
# Out:
#                                                  url  \
# 0  https://twitter.com/mbezitznews/status/1615992...
# 1  https://twitter.com/darusoudsm/status/16131884...
# 2  https://twitter.com/Nipashetz/status/161290378...
# 3  https://twitter.com/spencer_minja/status/16128...
# 4  https://twitter.com/Mr_LazaroCO/status/1612760...
#
#                        date  \
# 0 2023-01-19 08:39:21+00:00
# 1 2023-01-11 14:58:00+00:00
# 2 2023-01-10 20:06:42+00:00
# 3 2023-01-10 17:52:50+00:00
# 4 2023-01-10 10:37:39+00:00
#
#                                           rawContent  \
# 0  Majanga mikopo ya ujasiriamali\n\nSababu za Dk...
# 1  Uzinduzi wa Asasi ya kilimo Biashara na Uchumi...
# 2  #HABARI Chuo kikuu cha Dar es Salaam kimezindu...
# 3  Leo tumefanya uzinduzi wa “Dar es Salaam Unive...
# 4  Today I attend Duane launching events at Unive...
#
#                                      renderedContent                   id  \
# ...
