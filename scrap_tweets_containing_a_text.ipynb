# %%
import pandas as pd
import snscrape.modules.twitter as sntwitter
import itertools

# %%
num_of_tweets = 10
text_contained = "kilimo"

# %%
data = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(text_contained).get_items(), num_of_tweets))

# %%
data.head()
# Out:
#                                                  url  \
# 0  https://twitter.com/joackcompany/status/161642...
# 1  https://twitter.com/SethNzogya/status/16164142...
# 2  https://twitter.com/kamjoro_nanyuki/status/161...
# 3  https://twitter.com/JicentThoughts/status/1616...
# 4  https://twitter.com/MalemboLE/status/161641147...
#
#                        date  \
# 0 2023-01-20 13:14:14+00:00
# 1 2023-01-20 12:36:04+00:00
# 2 2023-01-20 12:34:35+00:00
# 3 2023-01-20 12:25:26+00:00
# 4 2023-01-20 12:25:02+00:00
#
#                                           rawContent  \
# 0  OFA OFA: TUNAUZA MIZANI YA KISASA YA KUPIMIA U...
# 1  wanajifunza *KILIMO CHA MPIRA nchini MALAYA* t...
# 2         @GukenaFMKenya Present from nanyuki kilimo
# 3  Nilisikia vijana hawatakiwi kubet!!\nEt wajihu...
# 4  Kaka Mponda  fafanua kivipi wazungu wamefanya ...
#
#                                      renderedContent                   id  \
# ...
